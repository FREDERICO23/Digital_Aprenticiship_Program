# %%
# Downloading the dataset 

import requests

download_url ='https://raw.githubusercontent.com/onaio/ona-tech/master/data/water_points.json'
target_json_path = 'water_points.json'

response = requests.get(download_url)
response.raise_for_status() #check if request was successful
with open(target_json_path, 'wb') as f:
    f.write(response.content)

print('Download finished.')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# C:\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# C:\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# ...

# %%
import pandas as pd
resources = pd.read_json('water_points.json')
type(resources)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.set_option('display.max.columns', None)
resources.tail()
# Out:
#     water_pay                 respondent research_asst_name water_used_season  \
# 707        no                  community         Emmanuel y        year_round
# 708        no  local_authority community         Emmanuel y        year_round
# 709        no  local_authority community         Emmanuel y        year_round
# 710        no                  community          abu seidu        year_round
# 711        no                  community                 Sa        year_round
#
#     _bamboo_dataset_id _deleted_at water_point_condition     _xform_id_string  \
# 707                            NaT           functioning  _08_Water_points_CV
# 708                            NaT                broken  _08_Water_points_CV
# 709                            NaT                broken  _08_Water_points_CV
# 710                            NaT           functioning  _08_Water_points_CV
# 711                            NaT           functioning  _08_Water_points_CV
#
# ...

# %%
resources.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 712 entries, 0 to 711
# Data columns (total 48 columns):
# water_pay                      712 non-null object
# respondent                     712 non-null object
# research_asst_name             712 non-null object
# water_used_season              712 non-null object
# _bamboo_dataset_id             712 non-null object
# _deleted_at                    0 non-null datetime64[ns]
# water_point_condition          712 non-null object
# _xform_id_string               712 non-null object
# other_point_1km                712 non-null object
# _attachments                   712 non-null object
# communities_villages           712 non-null object
# end                            712 non-null object
# animal_number                  528 non-null object
# water_point_id                 712 non-null object
# start                          712 non-null object
# water_connected                712 non-null object
# ...

# %%
resources.shape
# Out:
# (712, 48)

# %%
import numpy as np
resources.describe(include=np.object)
# Out:
#        water_pay respondent research_asst_name water_used_season  \
# count        712        712                712               712
# unique         3          4                 30                 6
# top           no  community                 HM        year_round
# freq         693        640                214               503
#
#        _bamboo_dataset_id water_point_condition     _xform_id_string  \
# count                 712                   712                  712
# unique                  1                     6                    1
# top                                 functioning  _08_Water_points_CV
# freq                  712                   590                  712
#
#        other_point_1km                                 _attachments  \
# count              712                                          712
# unique               2                                          711
# top                yes  [north_ghana/attachments/1358081512606.jpg]
# ...

# %%
resources['water_point_condition'].value_counts()
# Out:
# functioning           590
# broken                 40
# abandoned              36
# newly_constructed      28
# under_construction     16
# na_dn                   2
# Name: water_point_condition, dtype: int64

# %%
# NUMBER OF WATER POINTS THAT ARE FUNCTUIONAL

is_functioning = resources['water_point_condition']=='functioning'
is_functioning.value_counts()
# Out:
# True     590
# False    122
# Name: water_point_condition, dtype: int64

# %%
# NUMBER OF WATER POINTS PER COMMUNITY

water_points = resources.groupby('communities_villages').water_point_condition.value_counts()
water_points
# Out:
# communities_villages  water_point_condition
# Abanyeri              functioning               3
#                       newly_constructed         1
# Akpari-yeri           functioning               3
# Alavanyo              functioning               2
#                       abandoned                 1
#                                                ..
# Zukpeni               abandoned                 3
#                       functioning               2
#                       broken                    1
# Zundem                functioning              29
#                       under_construction        1
# Name: water_point_condition, Length: 134, dtype: int64

# %%
# COMMUNITY RANK BY BROKEN WATER POINTS in PERCENTAGE
broken_water_points = resources.loc[resources['water_point_condition']=='broken','communities_villages'].value_counts('broken','communities_villages')
broken_water_points
# Out:
# Nayoku         0.150
# Kubore         0.100
# Loagri_1_      0.100
# Zanwara        0.050
# Gbaarigu       0.050
# Soo            0.050
# Namgurima      0.050
# Vundema        0.050
# Bandem         0.050
# Arigu          0.050
# Jagsa          0.025
# Luisa          0.025
# Kpatarigu      0.025
# Longsa         0.025
# Tantala        0.025
# Banyangsa      0.025
# Kaasa          0.025
# Guuta          0.025
# Zukpeni        0.025
# Nyankpiensa    0.025
# Kanwaasa       0.025
# Zogsa          0.025
# Name: communities_villages, dtype: float64

# %%
pip install jupytext
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
#   File "<ipython-input-2-c24063cd8f59>", line 1
#     git add *
#           ^
# SyntaxError: invalid syntax
